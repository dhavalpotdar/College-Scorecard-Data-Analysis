# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
import requests
import os
import zipfile, io

# %% [markdown]
# # Data

# %% [markdown]
# ### Wrangling

# %% [markdown]
# Use the [URL](https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip) for College Scorecard Raw Data from www.data.gov to download the file: `CollegeScorecare_Raw_Data.zip`. Unzip the data into a folder called `data`.
#
# _Note: Preferably create the folder_`data`_in a parent directory since the extracted data is about 2.5 GB in size. Using Version Control to track such a large folder and pushing it to a repository will soon turn into a headache._ <br><br>
# Here is the Python code to do the same:

# %%
folder_name = r'../data'

if not os.path.exists(folder_name):
    os.makedirs(folder_name)


url = r'https://ed-public-download.app.cloud.gov/downloads/CollegeScorecard_Raw_Data.zip'
response = requests.get(url, stream = True)

with zipfile.ZipFile(io.BytesIO(response.content)) as zf:
    for elem in zf.namelist():
        zf.extract(elem, '../data')

# %% [markdown]
# For this analysis, we will be using the data for the **Academic Year 2017-18** as reported by all the [Integrated Postsecondary Education Data System (IPEDS)](https://nces.ed.gov/ipeds/) institutions. <br> The data resides in a csv file called: `MERGED2017_18_PP.csv`

# %%
df_raw = pd.read_csv('../data/CollegeScorecard_Raw_Data/MERGED2017_18_PP.csv', low_memory = False)

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7058 entries, 0 to 7057
# Columns: 1977 entries, UNITID to OMENRUP_PARTTIME_POOLED_SUPP
# dtypes: float64(1894), int64(14), object(69)
# memory usage: 106.5+ MB

# %% [markdown]
# ___________________________________________________________________________________________________________________________

# %% [markdown]
# The raw data comprises of 1977 columns. The structure of the data violates the definition of Tidy Data according to Hadely Wickham's Paper on Tidy Data which can be found [here](https://www.jstatsoft.org/article/view/v059i10). <br> Due to this reason, many columns are not variable names; instead, they are possible values. This drastically increases the number of columns in the dataset. In short, the number of variables is far fewer than the number of columns in the dataset.

# %% [markdown]
# For this Analysis, we will be selecting a subset of the variables. You can go through the [full documentation](https://collegescorecard.ed.gov/data/documentation/) to figure out which variables strike as most interesting to you.
#
#
# Here, I have selected the following variables:
#
# - __UNITID__: <br>Data files are provided at the UNITID level, which is the unique identification number assigned to postsecondary institutions as surveyed through IPEDS - Integrated Postsecondary Education Data System.
#
#
# - __INSTNM__: <br>The institution’s name, as reported in IPEDS.
#
#
# - __CITY, STABBR__: <br>As reported in IPEDS.
#
#
# - __NUMBRANCH__: <br>The branch campus column identifies the number of branch campuses at that institution.
#
#
# - __HIGHDEG__: <br>Highest award identifies the highest award level conferred at the institution.
#
#
# - __PREDDEG__: <br>Predominant undergraduate award identifies the type of award that the institution primarily confers; for instance, an institution that awards 40 percent bachelor’s degrees, 30 percent associate degrees, and 30 percent certificate programs would be classified as predominantly bachelor’s degree awarding.
#
#
# - __CONTROL__: <br>This element is reported directly to IPEDS, and identifies whether the institution’s governance structure is public, private nonprofit, or private for-profit.
#
#
# - __DISTANCEONLY__: <br>Institutions are identified as distance education-only if all their programs are available only via distance education.
#
#
# - __TUITFTE__: <br>The net tuition revenue per full-time equivalent (FTE) student uses tuition revenue minus discounts and allowances, and divides that by the number of FTE undergraduate and graduate students.
#
#
# - __AVGFACSAL__: <br>The average faculty salary produces the average faculty salary per month, by dividing the total salary outlays by the number of months worked for all full-time, nonmedical instructional staff.
#
#
# - __ADM_RATE_ALL__: <br>Colleges report to IPEDS their Fall admissions rate, defined as the number of admitted undergraduates divided by the number of undergraduates who applied. ADM_RATE_ALL represents the admissions rate across all campuses, defined as the total number of admitted undergraduates across all branches divided by the total number of undergraduates who applied across all branches.
#
#
# - __SATVR25, SATVR75, SATMT25, SATMT75, ACTCM25, ACTCM75__: <br>The files include the 25th and 75th percentiles of SAT reading (SATVR* for _25 and _75), writing (SATWR* for _25 and _75), math (SATMT* for _25 and _75) NOTE: WR is has no data and should be dropped.
#
#
# - __UGDS__: <br>This element includes the number of degree/certificate-seeking undergraduates enrolled in the fall, as reported in the IPEDS Fall Enrollment component.
#
#
# - __UG25ABV__: <br>This element identifies the share of students enrolled as of the institutions official fall census date (or October 15 of the IPEDS collection year, whichever is earlier) who are ages 25 and over.
#
#
# - __PCTFLOAN__: <br>This element, as reported in the IPEDS Student Financial Aid (SFA) component, shows the share of undergraduate students who received federal loans in a given year.
#
#
# - __CDR3__: <br>Cohort default rates are produced annually as an institutional accountability metric; institutions with high default rates may lose access to federal financial aid. The three-year cohort default rate (CDR3) represents a snapshot in time.

# %% [markdown]
# Lets select these variables of interest from the `df_raw` and store it in `df`:

# %%
cols_of_interest = ['UNITID', 'INSTNM', 'CITY', 'STABBR', 'NUMBRANCH', 'HIGHDEG', 'PREDDEG', 'CONTROL', 'DISTANCEONLY', 
                    'TUITFTE', 'AVGFACSAL', 'ADM_RATE_ALL', 'SATVR25', 'SATVR75', 'SATMT25', 'SATMT75', 'ACTCM25', 
                    'ACTCM75', 'UGDS', 'UG25ABV', 'PCTFLOAN', 'CDR3']

data_of_interest = df_raw[cols_of_interest]

# %%
data_of_interest.shape
# Out:
# (7058, 22)

# %% [markdown]
# ### Assessing and Cleaning

# %%
df_clean = data_of_interest.copy()

# %% [markdown]
# #### Turn column names to lower case:

# %%
df_clean.rename( columns = lambda col: col.strip().lower(), inplace = True )

# %% [markdown]
# #### Check for NULL entries:

# %%
df_clean.isnull().any()
# Out:
# unitid          False
# instnm          False
# city            False
# stabbr          False
# numbranch       False
# highdeg         False
# preddeg         False
# control         False
# distanceonly     True
# tuitfte          True
# avgfacsal        True
# adm_rate_all     True
# satvr25          True
# satvr75          True
# satmt25          True
# satmt75          True
# actcm25          True
# actcm75          True
# ugds             True
# ug25abv          True
# pctfloan         True
# cdr3             True
# dtype: bool

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7058 entries, 0 to 7057
# Data columns (total 22 columns):
# unitid          7058 non-null int64
# instnm          7058 non-null object
# city            7058 non-null object
# stabbr          7058 non-null object
# numbranch       7058 non-null int64
# highdeg         7058 non-null int64
# preddeg         7058 non-null int64
# control         7058 non-null int64
# distanceonly    6614 non-null float64
# tuitfte         6593 non-null float64
# avgfacsal       4209 non-null float64
# adm_rate_all    2230 non-null float64
# satvr25         1233 non-null float64
# satvr75         1233 non-null float64
# satmt25         1233 non-null float64
# satmt75         1233 non-null float64
# actcm25         1289 non-null float64
# actcm75         1289 non-null float64
# ugds            6312 non-null float64
# ug25abv         6239 non-null float64
# pctfloan        6291 non-null float64
# cdr3            6055 non-null float64
# dtypes: float64(14), int64(5), object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# There seem to be a lot of NULL values for the SAT and ACT data. We will have to consider this during the analysis.

# %% [markdown]
# #### Many Categorical variables have been encoded as Numeric, as evident from the documentation. Let's convert those back:

# %% [markdown]
# - **`stabbr`**:

# %%
df_clean.stabbr.unique()
# Out:
# array(['AL', 'AK', 'WA', 'AZ', 'NM', 'AR', 'CA', 'MN', 'CO', 'CT', 'NY',
#        'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'MI', 'IA', 'KS',
#        'MO', 'KY', 'LA', 'ME', 'MD', 'MA', 'MS', 'MT', 'NE', 'NV', 'NH',
#        'NJ', 'NC', 'ND', 'OH', 'WV', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD',
#        'TN', 'TX', 'UT', 'VT', 'VA', 'WI', 'WY', 'AS', 'GU', 'MP', 'PR',
#        'FM', 'PW', 'VI', 'MH'], dtype=object)

# %%
df_clean.stabbr.nunique()
# Out:
# 59

# %% [markdown]
# 59? Last time I checked, the US had 50 states. Lets investigate this further. <br>Here is a list of all the states according to Wikipedia:

# %%
states = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA',
         'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR',
         'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

# %%
len(states)
# Out:
# 50

# %% [markdown]
# Lets isolate the additional 9 elements in `stabbr`:

# %%
set(df_clean.stabbr.unique()) - set(states)
# Out:
# {'AS', 'DC', 'FM', 'GU', 'MH', 'MP', 'PR', 'PW', 'VI'}

# %% [markdown]
# A quick Google search shows that these 9 abbrevations are Commonwealth/Territories. <br>We can conclude that all values in the `stabbr` column are valid.

# %% [markdown]
# Next, lets convert this column to type Categorical:

# %%
l = list(df_clean.stabbr.unique())

df_clean['stabbr'] = pd.Categorical(df_clean.stabbr, categories = l, ordered = False)

# %%
df_clean.stabbr.dtype
# Out:
# CategoricalDtype(categories=['AL', 'AK', 'WA', 'AZ', 'NM', 'AR', 'CA', 'MN', 'CO', 'CT',
#                   'NY', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'MI',
#                   'IA', 'KS', 'MO', 'KY', 'LA', 'ME', 'MD', 'MA', 'MS', 'MT',
#                   'NE', 'NV', 'NH', 'NJ', 'NC', 'ND', 'OH', 'WV', 'OK', 'OR',
#                   'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WI',
#                   'WY', 'AS', 'GU', 'MP', 'PR', 'FM', 'PW', 'VI', 'MH'],
#                  ordered=False)

# %% [markdown]
# - __`highdeg`__ and __`preddeg`__:

# %%
df_clean.highdeg.unique()
# Out:
# array([4, 2, 3, 1, 0], dtype=int64)

# %%
df_clean.preddeg.unique()
# Out:
# array([3, 2, 1, 4, 0], dtype=int64)

# %% [markdown]
# From the documentation, both the columns map the numeric value to categorical value as follows: <br>
#     - 4 : Graduate's Degree
#     - 3 : Bachelor's Degree
#     - 2 : Associate's Degree
#     - 1 : Certificate
#     - 0 : N/A

# %%
df_clean['highdeg'].replace(to_replace = {0: np.nan, 1:'Certificate', 2:"Associate's", 3:"Bachelor's", 
                                                       4:"Graduate's"}, 
                                         inplace = True)

df_clean['preddeg'].replace(to_replace = {0: np.nan, 1:'Certificate', 2:"Associate's", 3:"Bachelor's", 
                                                       4:"Graduate's"}, 
                                         inplace = True)

# %%
df_clean.highdeg.value_counts(), df_clean.preddeg.value_counts()
# Out:
# (Certificate    2259
#  Graduate's     2047
#  Associate's    1513
#  Bachelor's      762
#  Name: highdeg, dtype: int64, Certificate    2990
#  Bachelor's     2095
#  Associate's    1217
#  Graduate's      308
#  Name: preddeg, dtype: int64)

# %% [markdown]
# Let's compare the value counts with the original dataframe:<br>
#     - 4 : Graduate's Degree
#     - 3 : Bachelor's Degree
#     - 2 : Associate's Degree
#     - 1 : Certificate
#     - 0 : N/A

# %%
df.HIGHDEG.value_counts(), df.PREDDEG.value_counts()
# Out:
# (1    2259
#  4    2047
#  2    1513
#  3     762
#  0     477
#  Name: HIGHDEG, dtype: int64, 1    2990
#  3    2095
#  2    1217
#  0     448
#  4     308
#  Name: PREDDEG, dtype: int64)

# %% [markdown]
# Looks fine.

# %% [markdown]
# Now lets convert to categorical values according to the mapping:

# %%
df_clean['highdeg'] = pd.Categorical(df_clean.highdeg, categories = ['Certificate', "Associate's", "Bachelor's", "Graduate's"],
                                    ordered = True)

# %%
df_clean['preddeg'] = pd.Categorical(df_clean.preddeg, categories = ['Certificate', "Associate's", "Bachelor's", "Graduate's"],
                                    ordered = True)

# %% [markdown]
# - __`control`__:

# %%
df_clean.control.value_counts()
# Out:
# 3    2969
# 1    2063
# 2    2026
# Name: control, dtype: int64

# %% [markdown]
# From the documentation, the mapping is as follows:
#     - 1 : Public
#     - 2 : Private Nonprofit
#     - 3 : Private For-Profit

# %%
df_clean.control.replace(to_replace = {1: 'Public', 2: 'Private Nonprofit', 3: 'Private For-Profit'}, inplace = True)

# %%
df_clean['control'] = pd.Categorical(df_clean.control, categories = ['Public', 'Private Nonprofit', 'Private For-Profit'],
                                    ordered = False)

# %%
df_clean.control.value_counts()
# Out:
# Private For-Profit    2969
# Public                2063
# Private Nonprofit     2026
# Name: control, dtype: int64

# %% [markdown]
# - **`distanceonly`**:

# %%
df_clean.distanceonly.value_counts()
# Out:
# 0.0    6561
# 1.0      53
# Name: distanceonly, dtype: int64

# %% [markdown]
# From the documentation:
#     - 0 : No
#     - 1 : Yes

# %%
df_clean.distanceonly.replace(to_replace = {0.0: 'No', 1.0: 'Yes'}, inplace = True)

# %%
df_clean['distanceonly'] = pd.Categorical(df_clean.distanceonly, categories = ['No', 'Yes'], ordered = False)

# %%
df_clean.distanceonly.value_counts()
# Out:
# No     6561
# Yes      53
# Name: distanceonly, dtype: int64

# %% [markdown]
# - **`ugds`**:

# %% [markdown]
# UGDS is the number of Undergraduate students that enroll in an academic year. <br>
# This variable in the dataset has datatype `float`:

# %%
df_clean.ugds.dtype
# Out:
# dtype('float64')

# %% [markdown]
# Ideally it should be converted to dtype `int`, however the inability to convert a column having NaNs to dtype int is one of the known [limitations of pandas](http://pandas.pydata.org/pandas-docs/stable/user_guide/gotchas.html#support-for-integer-na) of Pandas. <br> For that reason we will leave the datatype as it is.

# %% [markdown]
# - Other variables: <br><br>
# The rest of the variables have the proper dtype. Lets save this cleaned dataframe for later use:

# %%
df_clean.to_csv('MERGED_2017_2018_cleaned.csv', index = None)

# %% [markdown]
# # Analysis

# %% [markdown]
# Lets read in the cleaned dataframe:

# %%
df = pd.read_csv('MERGED_2017_2018_cleaned.csv')

# %%
df.head()
# Out:
#    unitid                               instnm        city stabbr  numbranch  \
# 0  100654             Alabama A & M University      Normal     AL          1
# 1  100663  University of Alabama at Birmingham  Birmingham     AL          1
# 2  100690                   Amridge University  Montgomery     AL          1
# 3  100706  University of Alabama in Huntsville  Huntsville     AL          1
# 4  100724             Alabama State University  Montgomery     AL          1
#
#       highdeg     preddeg            control distanceonly  tuitfte  ...  \
# 0  Graduate's  Bachelor's             Public           No   9227.0  ...
# 1  Graduate's  Bachelor's             Public           No  11612.0  ...
# 2  Graduate's  Bachelor's  Private Nonprofit          Yes  14738.0  ...
# 3  Graduate's  Bachelor's             Public           No   8727.0  ...
# 4  Graduate's  Bachelor's             Public           No   9003.0  ...
#
#    satvr25  satvr75  satmt25  satmt75  actcm25  actcm75     ugds  ug25abv  \
# 0    365.0    485.0    360.0    495.0     16.0     19.0   4824.0   0.0758
# 1    440.0    630.0    550.0    740.0     21.0     28.0  12866.0   0.2296
# 2      NaN      NaN      NaN      NaN      NaN      NaN    322.0   0.8230
# 3    550.0    660.0    530.0    670.0     25.0     31.0   6917.0   0.1842
# 4    380.0    485.0    375.0    481.0     16.0     20.0   4189.0   0.0848
#
#    pctfloan   cdr3
# 0    0.7697  0.198
# 1    0.5207  0.059
# 2    0.8741  0.128
# 3    0.4278  0.074
# 4    0.7690  0.211
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Univariate Explorations:

# %% [markdown]
# Here we will look at distributions of the variables and try to answer some preliminary questions about the data.

# %% [markdown]
# #### Q. Lets look at `stabbr`. Which states have a greater or fewer number of institutes?

# %%
sb.set_style('dark')
plt.figure(figsize = (8, 16))

# plot
ax = sb.barplot(df.stabbr.value_counts().values, df.stabbr.value_counts().index, 
           palette = sb.color_palette('gnuplot_r', len(df.stabbr.value_counts())))

# annotate the bars
for p in ax.patches:
    width = p.get_width()
    plt.text(20+p.get_width(), p.get_y()+0.55*p.get_height(),
             '{:1.0f}'.format(width),
             ha='center', va='center', fontsize = 12)

# label the plot
plt.title('State-wise Distribution of Institutes', fontsize = 15)
plt.xlabel('Number of Institutes', fontsize = 13)
plt.ylabel('State Code', fontsize = 13)
plt.xticks([], [])
plt.yticks(fontsize = 12)

plt.tight_layout();

# %% [markdown]
# > - The state of California (CA) has by far the greatest number of institutes. <br><br>
# > - The states of New York (NY), Texas (TX), Florida (FL), Pennsylvania (PA), Ohio (OH) and Illinois (IL) have closely competing numbers. <br><br>
# > - The number of institutes in the rest of the states show a gradual decrease as seen in the figure. <br><br>
# > - Of the Commonwealth/Territories only the District of Columbia (DC), and Puerto Rico (PR) have a significant number of universities. The rest have a single university each.

# %% [markdown]
# #### Q. How is the distribution of the Number of Branches `numbranch`? What is the median number of branches per Institute?

# %%
sb.set_style('darkgrid')

# specify the bins
bins = np.arange(0, df.numbranch.max() + 1, 1)

# plot
plt.figure(figsize = (8,6))
plt.hist(data = df, x = 'numbranch', bins = bins)

# label
plt.title('Distribution of Number of Branches per Institute')
plt.xlabel('Number of Branches')
plt.ylabel('Count');

# %%
print(f"Percentage of all Universities having a single branch: {len(df.query('numbranch == 1'))/len(df) * 100}")
print(f"The median number of branches per institute: {df.numbranch.median()}")
# Out:
# Percentage of all Universities having a single branch: 69.32558798526495
# The median number of branches per institute: 1.0

# %% [markdown]
# Let's look at the outlier past the 70 mark:

# %%
df.query('numbranch > 70')
# Out:
#         unitid                                        instnm  \
# 648     131803       Strayer University-District of Columbia
# 3682    233684                   Strayer University-Virginia
# 4646    430184                   Strayer University-Maryland
# 4988    443766                  Strayer University-Tennessee
# 4989    443784               Strayer University-Pennsylvania
# 5217    449038                    Strayer University-Florida
# 5285    450298                   Strayer University-Delaware
# 5287    450377                    Strayer University-Alabama
# 5384    453163             Strayer University-North Carolina
# 5385    453215                 Strayer University-New Jersey
# 5526    456621              Strayer University-West Virginia
# 5645    458885                   Strayer University-Arkansas
# 5646    458919                    Strayer University-Georgia
# 5647    458955                Strayer University-Mississippi
# 5648    458964             Strayer University-South Carolina
# 5649    458973                      Strayer University-Texas
# 5704    459994              Strayer University-Global Region
# 6673  13180301         Strayer University-Takoma Park Campus
# 6876  23368401          Strayer University-Alexandria Campus
# 6877  23368402          Strayer University-Woodbridge Campus
# 6878  23368403            Strayer University-Manassas Campus
# 6879  23368404             Strayer University-Loudoun Campus
# 6880  23368405      Strayer University-Fredericksburg Campus
# 6881  23368407             Strayer University-Henrico Campus
# 6882  23368408        Strayer University-Chesterfield Campus
# 6883  23368409          Strayer University-Chesapeake Campus
# 6884  23368410        Strayer University-Newport News Campus
# 6885  23368411      Strayer University-Virginia Beach Campus
# 6950  43018401           Strayer University-Rockville Campus
# 6951  43018402        Strayer University-Anne Arundel Campus
# ...        ...                                           ...
# 6982  44903805          Strayer University-Baymeadows Campus
# 6983  44903806  Strayer University-Palm Beach Gardens Campus
# 6984  44903808     Strayer University-Fort Lauderdale Campus
# 6985  44903809             Strayer University-Miramar Campus
# 6992  45037701          Strayer University-Huntsville Campus
# 6995  45316301            Strayer University-North Charlotte
# 6996  45316302            Strayer University-South Charlotte
# 6997  45316303       Strayer University-North Raleigh Campus
# 6998  45316304          Strayer University-Greensboro Campus
# 6999  45316305        Strayer University-Huntersville Campus
# 7000  45316306       Strayer University-South Raleigh Campus
# 7001  45321501         Strayer University-Willingboro Campus
# 7002  45321503                 Strayer University-Piscataway
# 7010  45891901                Strayer University-Cobb Campus
# 7011  45891902              Strayer University-Morrow Campus
# 7012  45891903             Strayer University-Roswell Campus
# 7013  45891904        Strayer University-Douglasville Campus
# 7014  45891905            Strayer University-Lithonia Campus
# 7015  45891906            Strayer University-Savannah Campus
# 7016  45891907             Strayer University-Augusta Campus
# 7017  45891908                   Strayer University-Columbus
# 7018  45896401            Strayer University-Columbia Campus
# 7019  45896402          Strayer University-Charleston Campus
# 7020  45897301                     Strayer University-Irving
# 7021  45897303          Strayer University-Northwest Houston
# 7022  45897304                      Strayer University-Plano
# 7023  45897305                 Strayer University-Cedar Hill
# 7024  45897306               Strayer University-North Dallas
# 7025  45897307                Strayer University-San Antonio
# 7026  45897308                   Strayer University-Stafford
#
#                     city stabbr  numbranch     highdeg     preddeg  \
# 648           Washington     DC         73  Graduate's  Bachelor's
# 3682           Arlington     VA         73  Graduate's  Bachelor's
# 4646            Suitland     MD         73  Graduate's  Bachelor's
# 4988             Memphis     TN         73  Graduate's  Bachelor's
# 4989             Trevose     PA         73  Graduate's  Bachelor's
# 5217               Tampa     FL         73  Graduate's  Bachelor's
# 5285              Newark     DE         73  Graduate's  Bachelor's
# 5287          Birmingham     AL         73  Graduate's  Bachelor's
# 5384         Morrisville     NC         73  Graduate's  Bachelor's
# 5385         Cherry Hill     NJ         73  Graduate's  Bachelor's
# 5526         Scott Depot     WV         73  Graduate's  Bachelor's
# 5645         Little Rock     AR         73  Graduate's  Bachelor's
# 5646             Atlanta     GA         73  Graduate's  Bachelor's
# 5647             Jackson     MS         73  Graduate's  Bachelor's
# 5648          Greenville     SC         73  Graduate's  Bachelor's
# 5649              Austin     TX         73  Graduate's  Bachelor's
# 5704          Washington     DC         73  Graduate's  Bachelor's
# 6673          Washington     DC         73         NaN         NaN
# 6876          Alexandria     VA         73         NaN         NaN
# 6877          Woodbridge     VA         73         NaN         NaN
# 6878            Manassas     VA         73         NaN         NaN
# 6879             Ashburn     VA         73         NaN         NaN
# 6880      Fredericksburg     VA         73         NaN         NaN
# 6881          Glen Allen     VA         73         NaN         NaN
# 6882          Midlothian     VA         73         NaN         NaN
# 6883          Chesapeake     VA         73         NaN         NaN
# 6884        Newport News     VA         73         NaN         NaN
# 6885      Virginia Beach     VA         73         NaN         NaN
# 6950           Rockville     MD         73         NaN         NaN
# 6951        Millersville     MD         73         NaN         NaN
# ...                  ...    ...        ...         ...         ...
# 6982        Jacksonville     FL         73         NaN         NaN
# 6983  Palm Beach Gardens     FL         73         NaN         NaN
# 6984     Fort Lauderdale     FL         73         NaN         NaN
# 6985             Miramar     FL         73         NaN         NaN
# 6992          Huntsville     AL         73         NaN         NaN
# 6995           Charlotte     NC         73         NaN         NaN
# 6996           Charlotte     NC         73         NaN         NaN
# 6997             Raleigh     NC         73         NaN         NaN
# 6998          Greensboro     NC         73         NaN         NaN
# 6999             Raleigh     NC         73         NaN         NaN
# 7000             Raleigh     NC         73         NaN         NaN
# 7001         Willingboro     NJ         73         NaN         NaN
# 7002          Piscataway     NJ         73         NaN         NaN
# 7010             Atlanta     GA         73         NaN         NaN
# 7011              Morrow     GA         73         NaN         NaN
# 7012             Roswell     GA         73         NaN         NaN
# 7013        Douglasville     GA         73         NaN         NaN
# 7014            Lithonia     GA         73         NaN         NaN
# 7015            Savannah     GA         73         NaN         NaN
# 7016             Augusta     GA         73         NaN         NaN
# 7017            Columbus     GA         73         NaN         NaN
# 7018            Columbia     SC         73         NaN         NaN
# 7019    North Charleston     SC         73         NaN         NaN
# 7020              Irving     TX         73         NaN         NaN
# 7021             Houston     TX         73         NaN         NaN
# 7022               Plano     TX         73         NaN         NaN
# 7023          Cedar Hill     TX         73         NaN         NaN
# 7024              Dallas     TX         73         NaN         NaN
# 7025         San Antonio     TX         73         NaN         NaN
# 7026            Stafford     TX         73         NaN         NaN
#
#                  control distanceonly  tuitfte  ...  satvr25  satvr75  \
# 648   Private For-Profit           No  14079.0  ...      NaN      NaN
# 3682  Private For-Profit           No  13950.0  ...      NaN      NaN
# 4646  Private For-Profit           No  13615.0  ...      NaN      NaN
# 4988  Private For-Profit           No  12700.0  ...      NaN      NaN
# 4989  Private For-Profit           No  13533.0  ...      NaN      NaN
# 5217  Private For-Profit           No  14280.0  ...      NaN      NaN
# 5285  Private For-Profit           No  13853.0  ...      NaN      NaN
# 5287  Private For-Profit           No  13095.0  ...      NaN      NaN
# 5384  Private For-Profit           No  12964.0  ...      NaN      NaN
# 5385  Private For-Profit           No  13316.0  ...      NaN      NaN
# 5526  Private For-Profit           No  13346.0  ...      NaN      NaN
# 5645  Private For-Profit           No  13015.0  ...      NaN      NaN
# 5646  Private For-Profit           No  12582.0  ...      NaN      NaN
# 5647  Private For-Profit           No  13077.0  ...      NaN      NaN
# 5648  Private For-Profit           No  13141.0  ...      NaN      NaN
# 5649  Private For-Profit           No  12241.0  ...      NaN      NaN
# 5704  Private For-Profit           No  13087.0  ...      NaN      NaN
# 6673  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6876  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6877  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6878  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6879  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6880  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6881  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6882  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6883  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6884  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6885  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6950  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6951  Private For-Profit          NaN      NaN  ...      NaN      NaN
# ...                  ...          ...      ...  ...      ...      ...
# 6982  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6983  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6984  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6985  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6992  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6995  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6996  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6997  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6998  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 6999  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7000  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7001  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7002  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7010  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7011  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7012  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7013  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7014  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7015  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7016  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7017  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7018  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7019  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7020  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7021  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7022  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7023  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7024  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7025  Private For-Profit          NaN      NaN  ...      NaN      NaN
# 7026  Private For-Profit          NaN      NaN  ...      NaN      NaN
#
#       satmt25  satmt75  actcm25  actcm75    ugds  ug25abv  pctfloan   cdr3
# 648       NaN      NaN      NaN      NaN   687.0   0.8726    0.7210  0.106
# 3682      NaN      NaN      NaN      NaN  4256.0   0.8862    0.5652  0.106
# 4646      NaN      NaN      NaN      NaN  2286.0   0.8875    0.6647  0.106
# 4988      NaN      NaN      NaN      NaN  2049.0   0.8367    0.8790  0.106
# 4989      NaN      NaN      NaN      NaN  1788.0   0.8362    0.7827  0.106
# 5217      NaN      NaN      NaN      NaN  1603.0   0.9085    0.7118  0.106
# 5285      NaN      NaN      NaN      NaN   267.0   0.8839    0.6951  0.106
# 5287      NaN      NaN      NaN      NaN   666.0   0.8709    0.8263  0.106
# 5384      NaN      NaN      NaN      NaN  3980.0   0.8435    0.8381  0.106
# 5385      NaN      NaN      NaN      NaN   770.0   0.8679    0.7150  0.106
# 5526      NaN      NaN      NaN      NaN   142.0   0.8873    0.7908  0.106
# 5645      NaN      NaN      NaN      NaN   219.0   0.8447    0.8622  0.106
# 5646      NaN      NaN      NaN      NaN  5529.0   0.8495    0.8277  0.106
# 5647      NaN      NaN      NaN      NaN   283.0   0.6537    0.8636  0.106
# 5648      NaN      NaN      NaN      NaN  1831.0   0.8438    0.7915  0.106
# 5649      NaN      NaN      NaN      NaN  1749.0   0.8834    0.7304  0.106
# 5704      NaN      NaN      NaN      NaN  5543.0   0.8456    0.4715  0.106
# 6673      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6876      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6877      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6878      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6879      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6880      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6881      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6882      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6883      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6884      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6885      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6950      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6951      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# ...       ...      ...      ...      ...     ...      ...       ...    ...
# 6982      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6983      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6984      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6985      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6992      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6995      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6996      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6997      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6998      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 6999      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7000      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7001      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7002      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7010      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7011      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7012      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7013      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7014      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7015      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7016      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7017      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7018      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7019      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7020      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7021      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7022      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7023      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7024      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7025      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
# 7026      NaN      NaN      NaN      NaN     NaN      NaN       NaN  0.106
#
# [74 rows x 22 columns]

# %% [markdown]
# We can see these branches are part of 'Strayer University'. Let's look at how these branches are distributed across different states:

# %%
# plot
plt.figure(figsize = (7, 4))
sb.barplot(x = df.query('numbranch > 70').groupby('stabbr').count().numbranch.sort_values(ascending = False).index, 
           y= df.query('numbranch > 70').groupby('stabbr').count().numbranch.sort_values(ascending = False).values, 
          color = sb.color_palette()[0])

# label
plt.title('State-wise Distribution of Strayer University Campuses', fontsize = 13)
plt.xlabel('State Code', fontsize = 11)
plt.ylabel('Count', fontsize = 11)
plt.xticks(fontsize = 11);

# %% [markdown]
# > - The median number of branches per Institute in the US is 1.
# > - Strayer University has the highest number of branches.
# > - The branches of Strayer University are spread across 16 states with the greatest number being in the state of Virginia.
